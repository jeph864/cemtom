# %%
from cemtom.dataset._20newgroup import fetch_dataset
from cemtom.preprocessing import Preprocessor

# %%
token_dict={
    "doc_start_token": '<s>',
    "doc_end_token":'</s>',
    "unk_token":'<unk>',
    "email_token":'<email>',
    "url_token":'<url>',
    "number_token":'<number>',
    "alpha_num_token":'<alpha_num>'
}
preprocessor = Preprocessor(stopwords_list="english", remove_spacy_stopwords = False,
                            token_dict=token_dict, use_spacy_tokenizer=True,
                           max_df = 0.80)
dataset = fetch_dataset(remove=("headers", "footers", "quotes"))
dataset = preprocessor.preprocess(None, dataset=dataset, num_processes=None)
# Out:
# Starting to extract the dataset
# 100%|██████████| 18846/18846 [00:00<00:00, 225182.61it/s]
# 100%|██████████| 18846/18846 [00:03<00:00, 5111.90it/s]
# /home/abijuru/.conda/envs/cemtom/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:394: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['alpha_num', 'email', 'number', 'unk', 'url'] not in stop_words.
#   warnings.warn(
# Filtering 18846
# vocab created 72149

# %%
# Out:
# {'bashers': 5499,
#  'pens': 46614,
#  'fans': 22147,
#  'pretty': 49226,
#  'confused': 12610,
#  'lack': 34993,
#  'kind': 34210,
#  'posts': 48570,
#  'recent': 51709,
#  'massacre': 38318,
#  'devils': 16628,
#  'bit': 6719,
#  'puzzled': 50465,
#  'relieved': 52508,
#  'put': 50442,
#  'end': 20030,
#  'pittsburghers': 47686,
#  'relief': 52503,
#  'praise': 48765,
#  'man': 37831,
#  'killing': 34179,
#  'worse': 70259,
#  'thought': 63497,
#  'jagr': 32721,
#  'showed': 57220,
#  'regular': 52277,
#  'season': 56028,
#  'stats': 60004,
#  'lot': 36858,
#  'fo': 23440,
#  'fun': 24440,
#  'watch': 68963,
#  'playoffs': 47885,
#  'bowman': 7594,
#  'couple': 13685,
#  'games': 24746,
#  'beat': 5754,
#  'pulp': 50272,
#  'jersey': 32951,
#  'disappointed': 17190,
#  'islanders': 32427,
#  'lose': 36842,
#  'final': 22870,
#  'game': 24735,
#  'rule': 54568,
#  'brother': 8063,
#  'market': 38149,
#  'high': 28457,
#  'performance': 46723,
#  'video': 68039,
#  'card': 9263,
#  'supports': 61508,
#  'vesa': 67915,
#  'local': 36612,
#  'bus': 8527,
#  'number': 43564,
#  'mb': 38592,
#  'ram': 51106,
#  'suggestions': 61171,
#  'ideas': 29853,
#  'diamond': 16755,
#  'stealth': 60053,
#  'pro': 49430,
#  'orchid': 44700,
#  'farenheit': 22183,
#  'ati': 4229,
#  'graphics': 26235,
#  'ultra': 65786,
#  'vlb': 68336,
#  'post': 48519,
#  'email': 19693,
#  'matt': 38453,
#  'finally': 22877,
#  'dream': 18422,
#  'mediterranean': 38957,
#  'area': 3405,
#  'greater': 26339,
#  'years': 71517,
#  'holocaust': 28859,
#  'numbers': 43571,
#  'july': 33381,
#  'usa': 67118,
#  'sweden': 61801,
#  'april': 3224,
#  'cold': 11597,
#  'changed': 10084,
#  'calendar': 8849,
#  'mentioned': 39199,
#  'true': 65134,
#  'azeri': 4845,
#  'women': 70099,
#  'children': 10441,
#  'pay': 46290,
#  'price': 49275,
#  'raped': 51216,
#  'killed': 34169,
#  'tortured': 64281,
#  'armenians': 3567,
#  'hearded': 27886,
#  'called': 8896,
#  'geneva': 25142,
#  'convention': 13166,
#  'facist': 21916,
#  'ohhh': 44150,
#  'forgot': 23724,
#  'fight': 22775,
#  'killings': 34180,
#  'rapings': 51226,
#  'torture': 64280,
#  'kurds': 34882,
#  'turks': 65408,
#  'time': 63806,
#  'ohhhh': 44151,
#  'swedish': 61804,
#  'redcross': 51927,
#  'workers': 70203,
#  'lie': 36120,
#  'regional': 52233,
#  'killer': 34172,
#  'person': 46899,
#  'shoot': 57125,
#  'policy': 48184,
#  'search': 56012,
#  'turkish': 65399,
#  'planes': 47778,
#  'talking': 62288,
#  'turkey': 65395,
#  'government': 26063,
#  'announced': 2620,
#  'giving': 25548,
#  'weapons': 69109,
#  'azerbadjan': 4837,
#  'armenia': 3564,
#  'started': 59923,
#  'attack': 4301,
#  'karabag': 33626,
#  'province': 50013,
#  'plane': 47776,
#  'content': 13003,
#  'give': 25540,
#  'azeris': 4849,
#  'armenian': 3565,
#  'bread': 7767,
#  'butter': 8593,
#  'arms': 3604,
#  'personel': 46915,
#  'russian': 54661,
#  'army': 3608,
#  'scsi': 55922,
#  'dma': 17882,
#  'transfers': 64634,
#  'disks': 17466,
#  'data': 15048,
#  'devices': 16623,
#  'attached': 4295,
#  'important': 30434,
#  'feature': 22415,
#  'ability': 127,
#  'detach': 16462,
#  'device': 16621,
#  'frees': 24107,
#  'typically': 65589,
#  'multi': 41378,
#  'tasking': 62468,
#  'os': 44890,
#  'start': 59922,
#  'seeking': 56171,
#  'free': 24079,
#  'commands': 11889,
#  'ready': 51491,
#  'transfer': 64624,
#  'aquire': 3270,
#  'send': 56354,
#  'ide': 29841,
#  'busy': 8574,
#  'disk': 17453,
#  'seeked': 56167,
#  'transfered': 64626,
#  'alpha_num': 1956,
#  'lock': 36634,
#  'processes': 49496,
#  'wanting': 68842,
#  'irrespective': 32336,
#  'jasmine': 32823,
#  'drive': 18483,
#  'system': 62096,
#  'understanding': 66167,
#  'upsate': 67018,
#  'driver': 18488,
#  'modern': 40479,
#  'order': 44711,
#  'gain': 24641,
#  'compatability': 12084,
#  'inexpensive': 30988,
#  'program': 49608,
#  'formatters': 23758,
#  'buit': 8307,
#  'idea': 29842,
#  'work': 70192,
#  'ancient': 2407,
#  'tape': 62386,
#  'back': 4925,
#  'utility': 67236,
#  'freezes': 24121,
#  'direct': 17111,
#  'bought': 7539,
#  'tapes': 62393,
#  'techmar': 62641,
#  'mechanism': 38874,
#  'essentially': 20838,
#  'question': 50753,
#  'beckup': 5799,
#  'school': 55625,
#  'worked': 70201,
#  'lab': 34949,
#  'assistant': 4017,
#  'bunch': 8388,
#  'experimental': 21571,
#  'psychologists': 50154,
#  'bell': 6031,
#  'labs': 34977,
#  'visual': 68275,
#  'perception': 46673,
#  'memory': 39139,
#  'experiments': 21581,
#  'vector': 67647,
#  'type': 65565,
#  'displays': 17574,
#  'millisecond': 39860,
#  'refresh': 52149,
#  'rates': 51296,
#  'common': 11975,
#  'case': 9455,
#  'sec': 56059,
#  'practical': 48735,
#  'experimenters': 21579,
#  'milliseconds': 39861,
#  'steve': 60197,
#  'ae': 1084,
#  'dallas': 14855,
#  'tech': 62632,
#  'support': 61500,
#  'line': 36293,
#  'stuff': 60735,
#  'deleted': 15823,
#  'solution': 58677,
#  'problem': 49461,
#  'move': 41123,
#  'canada': 9012,
#  'yesterday': 71569,
#  'nj': 42989,
#  'pitt': 47674,
#  'abc': 72,
#  'la': 34946,
#  'cal': 8814,
#  'cbc': 9660,
#  'buff': 8245,
#  'bos': 7466,
#  'tsn': 65218,
#  'fox': 23911,
#  'mon': 40638,
#  'series': 56529,
#  'max': 38515,
#  'watching': 68971,
#  'hockey': 28754,
#  'odd': 43991,
#  'consecutive': 12766,
#  'nights': 42864,
#  'counted': 13633,
#  'pure': 50366,
#  'guess': 26721,
#  'tv': 65462,
#  'house': 29200,
#  'set': 56592,
#  'side': 57365,
#  'eye': 21820,
#  'afternoon': 1256,
#  'btw': 8165,
#  'commentaters': 11911,
#  'great': 26337,
#  'impressed': 30475,
#  'audience': 4411,
#  'schooled': 55628,
#  'lore': 36825,
#  'excellent': 21280,
#  'job': 33099,
#  'impartial': 30318,
#  'imo': 30291,
#  'yeah': 71510,
#  'good': 25931,
#  'bruin': 8093,
#  'sabre': 54769,
#  'telecasts': 62738,
#  'wow': 70307,
#  'paint': 45602,
#  'knew': 34435,
#  'fuhr': 24388,
#  'play': 47862,
#  'bet': 6293,
#  'bruins': 8094,
#  'wishing': 69931,
#  'christian': 10622,
#  'means': 38830,
#  'believes': 6016,
#  'divinity': 17819,
#  'jesus': 32974,
#  'safe': 54855,
#  'day': 15145,
#  'christmas': 10636,
#  'truelove': 65138,
#  'served': 56551,
#  'leftover': 35660,
#  'casserole': 9485,
#  'made': 37438,
#  'days': 15162,
#  'flaming': 23132,
#  'wings': 69827,
#  'pizza': 47713,
#  'hut': 29527,
#  'commercial': 11921,
#  'bait': 5103,
#  'blood': 7004,
#  'lamb': 35080,
#  'hard': 27443,
#  'task': 62465,
#  'cultures': 14483,
#  'animals': 2539,
#  'sacrifices': 54803,
#  'related': 52432,
#  'current': 14547,
#  'modernism': 40480,
#  'state': 59953,
#  'hmm': 28704,
#  'computers': 12294,
#  'cheers': 10293,
#  'kent': 33902,
#  'history': 28636,
#  'untrustworthy': 66886,
#  'thou': 63495,
#  'wilt': 69750,
#  'law': 35401,
#  'honestly': 28974,
#  'word': 70169,
#  'sin': 57655,
#  'restriction': 53273,
#  'kid': 34134,
#  'words': 70180,
#  'encompass': 19985,
#  'majestic': 37664,
#  'vision': 68253,
#  'thousands': 63508,
#  'individuals': 30886,
#  'quoting': 50874,
#  'context': 13018,
#  'interpreted': 31902,
#  'differently': 16898,
#  'applied': 3105,
#  'confines': 12552,
#  'original': 44810,
#  'expression': 21682,
#  'hymenaeus': 29599,
#  'beta': 6294,
#  'frater': 24041,
#  'superior': 61405,
#  'belong': 6058,
#  'included': 30647,
#  'merlinus': 39272,
#  'service': 56563,
#  'extremes': 21795,
#  'members': 39101,
#  'fervor': 22623,
#  'knowledge': 34481,
#  'reuss': 53446,
#  'background': 4948,
#  'surely': 61561,
#  'unusual': 66902,
#  'force': 23620,
#  'people': 46642,
#  'change': 10082,
#  'orders': 44717,
#  'carefully': 9298,
#  'dirty': 17151,
#  'laundry': 35372,
#  'remember': 52602,
#  'surface': 61568,
#  'skim': 57882,
#  'perspectives': 46931,
#  'encompassed': 19986,
#  'extend': 21708,
#  'individual': 30879,
#  'hope': 29035,
#  'show': 57213,
#  'room': 54224,
#  'difference': 16885,
#  'opinion': 44524,
#  'testing': 63083,
#  'limits': 36255,
#  'examine': 21236,
#  'issue': 32510,
#  'closely': 11257,
#  'karl': 33657,
#  'kellner': 33858,
#  'wealthy': 69101,
#  'austrian': 4497,
#  'industrialist': 30928,
#  'paper': 45783,
#  'chemist': 10323,
#  'grade': 26126,
#  'mason': 38302,
#  'founded': 23883,
#  'ordo': 44729,
#  'templi': 62841,
#  'orientis': 44800,
#  'traveled': 64788,
#  'widely': 69616,
#  'east': 19002,
#  'met': 39343,
#  'adepts': 806,
#  'instructed': 31595,
#  'specific': 59115,
#  'magical': 37483,
#  'practices': 48741,
#  'efforts': 19308,
#  'develop': 16595,
#  'assisted': 4020,
#  'franz': 24034,
#  'hartmann': 27592,
#  'heinrich': 28046,
#  'klein': 34362,
#  'theodore': 63260,
#  'prior': 49372,
#  'joining': 33147,
#  'proclaimed': 49506,
#  'masonic': 38303,
#  'publication': 50196,
#  'oriflamme': 44803,
#  'death': 15276,
#  'succeeded': 61052,
#  'outer': 45079,
#  'head': 27819,
#  'jubilee': 33303,
#  'edition': 19200,
#  'published': 50205,
#  'taught': 62512,
#  'secret': 56089,
#  'sexual': 56685,
#  'magic': 37482,
#  'interesting': 31790,
#  'character': 10130,
#  'born': 7442,
#  'june': 33402,
#  'augsburg': 4448,
#  'entered': 20275,
#  'masonry': 38305,
#  'singer': 57688,
#  'journalist': 33235,
#  'possibly': 48518,
#  'spy': 59564,
#  'prussian': 50064,
#  'political': 48201,
#  'police': 48177,
#  'infiltrating': 31062,
#  'socialist': 58499,
#  'league': 35526,
#  'marx': 38271,
#  'daughter': 15097,
#  'husband': 29504,
#  'william': 69721,
#  'wynn': 70497,
#  'westcott': 69313,
#  'leader': 35509,
#  'golden': 25864,
#  'dawn': 15141,
#  'introduced': 32042,
#  'john': 33134,
#  'yarker': 71454,
#  'chartered': 10195,
#  'found': 23880,
#  'rites': 53899,
#  'memphis': 39142,
#  'mizraim': 40320,
#  'germany': 25282,
#  'attempts': 4325,
#  'concretize': 12414,
#  'settled': 56619,
#  'development': 16604,
#  'experienced': 21565,
#  'steady': 60043,
#  'growth': 26593,
#  'leadership': 35511,
#  'papus': 45801,
#  'france': 23998,
#  'rudolph': 54535,
#  'steiner': 60106,
#  'berlin': 6223,
#  'spencer': 59214,
#  'lewis': 35947,
#  'historic': 28629,
#  'meeting': 38978,
#  'crowley': 14204,
#  'occurred': 43937,
#  'wrote': 70410,
#  'accused': 488,
#  'revealing': 53461,
#  'secrets': 56102,
#  'looked': 36772,
#  'afresh': 1232,
#  'initiated': 31286,
#  'interpretation': 31896,
#  'magick': 37488,
#  'unfolded': 66313,
#  'appointed': 3117,
#  'supreme': 61542,
#  'holy': 28878,
#  'king': 34237,
#  'english': 20153,
#  'speaking': 59082,
#  'world': 70234,
#  'authorization': 4532,
#  'invoked': 32157,
#  'publishing': 50209,
#  'material': 38387,
#  'equinox': 20541,
#  'resigned': 53094,
#  'suffering': 61130,
#  'stroke': 60646,
#  'named': 41924,
#  'successor': 61070,
#  'book': 7345,
#  'translated': 64678,
#  'german': 25276,
#  'break': 7777,
#  'continuity': 13042,
#  'manyk': 38028,
#  'split': 59358,
#  'actively': 655,
#  'promulgating': 49737,
#  'earlier': 18953,
#  'revise': 53511,
#  'dthe': 18610,
#  'rituals': 53909,
#  'request': 52967,
#  'deeply': 15573,
#  'infusing': 31173,
#  'doctrines': 17959,
#  'aeon': 1091,
#  'revelation': 53466,
#  'introduction': 32045,
#  'ad': 702,
#  'veritatem': 67841,
#  'ix': 32631,
#  'edited': 19195,
#  'rex': 53577,
#  'summus': 61274,
#  'sanctissimus': 55087,
#  'caliph': 8885,
#  'united': 66475,
#  'states': 59962,
#  'america': 2135,
#  'samuel': 55062,
#  'weiser': 69227,
#  'reasons': 51590,
#  'real': 51502,
#  'point': 48120,
#  'publish': 50203,
#  'things': 63409,
#  'organization': 44763,
#  'represent': 52887,
#  'dogmatic': 18006,
#  'threat': 63527,
#  'principle': 49342,
#  'thelema': 63237,
#  'exercising': 21413,
#  'putting': 50456,
#  'complex': 12175,
#  'pictures': 47435,
#  'easy': 19015,
#  'answers': 2713,
#  'picture': 47433,
#  'leaves': 35585,
#  'interpretations': 31898,
#  'derived': 16251,
#  'dribble': 18455,
#  'faltering': 22096,
#  'purchased': 50356,
#  'clever': 11130,
#  'hucksters': 29337,
#  'ounce': 45040,
#  'courage': 13696,
#  'writing': 70391,
#  'aid': 1452,
#  'present': 49126,
#  'feeble': 22452,
#  'laughable': 35355,
#  'thrown': 63590,
#  'perspective': 46930,
#  'interjection': 31823,
#  'illustration': 30129,
#  'shows': 57235,
#  'express': 21678,
#  'larger': 35245,
#  'significance': 57481,
#  'difficult': 16909,
#  'apprehend': 3161,
#  'oto': 45009,
#  'qualified': 50633,
#  'assess': 3991,
#  'critical': 14075,
#  'pomposity': 48302,
#  'member': 39099,
#  'stand': 59829,
#  'allowed': 1894,
#  'continue': 13036,
#  'health': 27871,
#  'soft': 58564,
#  'abandoned': 51,
#  'moral': 40840,
#  'principles': 49344,
#  'strong': 60660,
#  'universal': 66491,
#  'kinship': 34262,
#  'arise': 3499,
#  'shackled': 56725,
#  'requirement': 52979,
#  'resolve': 53138,
#  'possibilities': 48511,
#  'find': 22888,
#  'calibre': 8869,
#  'intelligent': 31691,
#  'versed': 67878,
#  'arcane': 3334,
#  'usual': 67197,
#  'information': 31135,
#  'artists': 3765,
#  'geniuses': 25156,
#  'longstanding': 36756,
#  'sf': 56695,
#  'bay': 5629,
#  'heavily': 27951,
#  'involved': 32168,
#  'vouch': 68515,
#  'integrity': 31671,
#  'stands': 59855,
#  'questioned': 50759,
#  'moments': 40630,
#  'intuition': 32064,
#  'stop': 60390,
#  'requesting': 52970,
#  'initiation': 31289,
#  'body': 7180,
#  'happily': 27414,
#  'participating': 46013,
#  'social': 58495,
#  'groups': 26573,
#  'feasts': 22408,
#  'initiations': 31290,
#  'gnostic': 25755,
#  'mass': 38311,
#  'tastes': 62478,
#  'make': 37682,
#  'authority': 4531,
#  'politics': 48205,
#  'explanations': 21608,
#  'hypothesize': 29671,
#  'relay': 52460,
#  'understand': 66163,
#  'based': 5473,
#  'limited': 36249,
#  'contact': 12954,
#  'urge': 67072,
#  'ways': 69052,
#  'interpret': 31895,
#  'feel': 22466,
#  'strongly': 60666,
#  'sanctity': 55089,
#  'personal': 46906,
#  'freedom': 24085,
#  'preservation': 49138,
#  'comment': 11908,
#  'response': 53215,
#  'thread': 63522,
#  'invoke': 32156,
#  'stars': 59919,
#  'love': 36902,
#  'kirlian': 34285,
#  'imaging': 30174,
#  'faq': 22160,
#  'url': 67092,
#  'sp': 58952,
#  'nice': 42761,
#  'write': 70383,
#  'supportive': 61507,
#  'helping': 28127,
#  'build': 8286,
#  'connect': 12688,
#  'supply': 61497,
#  'aura': 4460,
#  'notion': 43389,
#  'heliocentric': 28073,
#  'galacticentric': 24656,
#  'report': 52863,
#  'eyes': 21835,
#  'role': 54150,
#  'ankara': 2566,
#  'ap': 2906,
#  'paragraph': 45836,
#  'turanist': 65351,
#  'premier': 49040,
#  'suleyman': 61206,
#  'demirel': 15946,
#  'criticized': 14085,
#  'ozal': 45475,
#  'brash': 7728,
#  'calls': 8911,
#  'influence': 31105,
#  'spoken': 59381,
#  'swath': 61779,
#  'turkic': 65397,
#  'peoples': 46644,
#  'stretching': 60596,
#  'adriatic': 971,
#  'sea': 55975,
#  'wall': 68772,
#  'china': 10470,
#  'fooling': 23563,
#  'ends': 20086,
#  'envisioned': 20394,
#  'pan': 45704,
#  'empire': 19868,
#  'balkans': 5160,
#  'caucasus': 9609,
#  'fascist': 22234,
#  'boasts': 7142,
#  'pre': 48803,
#  'empted': 19898,
#  'suggest': 61165,
#  'grey': 26422,
#  'wolf': 70071,
#  'teeth': 62707,
#  'attempt': 4322,
#  'stretch': 60590,
#  'cried': 14011,
#  'replied': 52847,
#  'appeal': 3035,
#  'info': 31113,
#  'modify': 40505,
#  'bbc': 5659,
#  'computer': 12286,
#  'speed': 59175,
#  'rpm': 54432,
#  'components': 12202,
#  'rec': 51665,
#  'section': 56109,
#  'lower': 36923,
#  'rate': 51292,
#  'designed': 16346,
#  'recording': 51862,
#  'low': 36916,
#  'rev': 53449,
#  'sort': 58823,
#  'bad': 5015,
#  'quid': 50798,
#  'upwards': 67043,
#  'jvc': 33471,
#  'mdp': 38801,
#  'ago': 1360,
#  'victim': 68015,
#  'squirted': 59641,
#  'fair': 21997,
#  'amount': 2228,
#  'model': 40457,
#  'teletype': 62783,
#  'acting': 642,
#  'turned': 65416,
#  'eruption': 20704,
#  'motor': 41033,
#  'starting': 59927,
#  'contacts': 12959,
#  'broke': 8013,
#  'mighty': 39745,
#  'spectacular': 59136,
#  'eyebrows': 21825,
#  'singed': 57687,
#  'plastic': 47826,
#  'safety': 54871,
#  'glass': 25592,
#  'cover': 13747,
#  'platen': 47834,
#  'flew': 23231,
#  'heart': 27898,
#  'attacks': 4307,
#  'beware': 6342,
#  'explosive': 21642,
#  'properties': 49800,
#  'vapor': 67489,
#  'court': 13711,
#  'disagree': 17167,
#  'stated': 59954,
#  'term': 62958,
#  'art': 3714,
#  'refering': 52082,
#  'explicitly': 21617,
#  'amendment': 2130,
#  'quote': 50867,
#  'employed': 19878,
#  'select': 56250,
#  'parts': 46052,
#  'constitution': 12893,
#  'preamble': 48813,
#  'declares': 15425,
#  'ordained': 44706,
#  'established': 20845,
#  'protects': 49939,
#  'bear': 5731,
#  'uerdugo': 65698,
#  'uriquidez': 67090,
#  'miller': 39841,
#  'decision': 15404,
#  'permitted': 46818,
#  'prosecution': 49889,
#  'possession': 48506,
#  'sawed': 55350,
#  'shotgun': 57184,
#  'defense': 15624,
#  'presented': 49130,
#  'testimony': 63082,
#  'accepted': 355,
#  'argument': 3464,
#  'military': 39813,
#  'held': 28058,
#  'protected': 49929,
#  'possess': 48502,
#  'successfully': 61066,
#  'fifty': 22770,
#  'appears': 3047,
#  'vis': 68228,
#  'conclusion': 12394,
#  'inescapable': 30970,
#  'concept': 12357,
#  'wording': 70173,
#  'major': 37669,
#  'commentator': 11913,
#  'half': 27153,
#  'century': 9882,
#  'cation': 9595,
#  'private': 49392,
#  'citizen': 10897,
#  'carry': 9399,
#  'firearms': 22961,
#  'peaceful': 46387,
#  'manner': 37951,
#  'subcommittee': 60815,
#  'committee': 11960,
#  'judiciary': 33337,
#  'senate': 56348,
#  'congress': 12641,
#  'session': 56588,
#  'february': 22423,
#  'rightfully': 53774,
#  'militias': 39820,
#  'militia': 39817,
#  'historical': 28630,
#  'basically': 5509,
#  'adult': 990,
#  'males': 37747,
#  'country': 13673,
#  'code': 11478,
#  'defines': 15664,
#  'armed': 3558,
#  'men': 39145,
#  'age': 1290,
#  'comprised': 12243,
#  'physically': 47357,
#  'capable': 9135,
#  'concert': 12369,
#  'expected': 21522,
#  'bearing': 5741,
#  'supplied': 61492,
#  'reason': 51580,
#  'phrase': 47334,
#  'explain': 21598,
#  'rationale': 51310,
#  'depending': 16132,
#  'centralization': 9858,
#  'power': 48649,
#  'occur': 43930,
#  'permit': 46815,
#  'tyranny': 65606,
#  'short': 57150,
#  'remain': 52567,
#  'perpetually': 46842,
#  'fear': 22390,
#  'debarred': 15289,
#  'strongest': 60663,
#  'retain': 53316,
#  'resort': 53153,
#  'protect': 49927,
#  'thomas': 63460,
#  'jefferson': 32895,
#  'proposal': 49843,
#  'virginia': 68205,
#  'papers': 45790,
#  'boyd': 7618,
#  'ed': 19162,
#  'preserve': 49141,
#  'liberties': 36045,
#  'rulers': 54572,
#  'warned': 68890,
#  'spirit': 59310,
#  'resistance': 53106,
#  'tree': 64850,
#  'liberty': 36051,
#  'refreshed': 52150,
#  'patriots': 46231,
#  'tyrants': 65608,
#  'letter': 35884,
#  'smith': 58278,
#  'democracy': 15953,
#  'padover': 45542,
#  'standing': 59849,
#  'disarmed': 17203,
#  'kingdom': 34238,
#  'europe': 21017,
#  'enforce': 20111,
#  'unjust': 66524,
#  'laws': 35420,
#  'sword': 61898,
#  'constitute': 12889,
#  'bands': 5242,
#  'troops': 65092,
#  'pretense': 49215,
#  'raised': 51076,
#  'noah': 43048,
#  'webster': 69141,
#  'examination': 21234,
#  'leading': 35514,
#  'federal': 22432,
#  'pamphlets': 45703,
#  'ford': 23630,
#  'repealed': 52774,
#  'pretend': 49211,
#  'argue': 3455,
#  'conditions': 12462,
#  'longer': 36740,
#  'ca': 8713,
#  'imagine': 30171,
#  'fill': 22840,
#  'detailed': 16471,
#  'argumentation': 3465,
#  'cryptography': 14326,
#  'lets': 35882,
#  'insist': 31492,
#  'discussing': 17375,
#  'gladly': 25572,
#  'discuss': 17370,
#  'matter': 38458,
#  'perry': 46862,
#  'metzger': 39458,
#  'gyroscopes': 26959,
#  'throughly': 63577,
#  'technique': 62652,
#  'countersteering': 13663,
#  'including': 30651,
#  'countersteer': 13661,
#  'corner': 13427,
#  'decreasing': 15482,
#  'radius': 50997,
#  'riding': 53738,
#  'circle': 10820,
#  'lies': 36135,
#  'eventually': 21114,
#  'leads': 35517,
#  'truth': 65180,
#  'official': 44082,
#  'doubts': 18244,
#  'front': 24247,
#  'brake': 7692,
#  'rear': 51565,
#  'avoid': 4726,
#  'locking': 36643,
#  'weight': 69199,
#  'takes': 62252,
#  'place': 47740,
#  'adhere': 817,
#  'full': 24413,
#  'licence': 36084,
#  'examiner': 21238,
#  'guidelines': 26743,
#  'laid': 35057,
#  'basic': 5507,
#  'rider': 53723,
#  'education': 19233,
#  'courses': 13707,
#  'choice': 10543,
#  'follow': 23513,
#  'surprises': 61605,
#  'mag': 37459,
#  'bmf': 7104,
#  'noise': 43093,
#  'fact': 21923,
#  ...}

# %%
# Out:
# ("\n\nI am sure some bashers of Pens fans are pretty confused about the lack\nof any kind of posts about the recent Pens massacre of the Devils. Actually,\nI am  bit puzzled too and a bit relieved. However, I am going to put an end\nto non-PIttsburghers' relief with a bit of praise for the Pens. Man, they\nare killing those Devils worse than I thought. Jagr just showed you why\nhe is much better than his regular season stats. He is also a lot\nfo fun to watch in the playoffs. Bowman should let JAgr have a lot of\nfun in the next couple of games since the Pens are going to beat the pulp out of Jersey anyway. I was very disappointed not to see the Islanders lose the final\nregular season game.          PENS RULE!!!\n\n",
#  'rec.sport.hockey')

# %%
import pandas as pd

# %%
octis_path = "../OCTIS/preprocessed_datasets/20NewsGroup"
mallet_path = "../data/mallet/20Newsgroup"
#data = ""
df = pd.read_csv(octis_path + "/corpus.tsv", sep='\t', header=None)
#train = df[df[3] == 'val']
df[[2,0]].to_csv(mallet_path + '/corpus.tsv', sep="\t", index=True, header=False)

# %%
train = df[df[1] == 'train']
#train = pd.concat([train, df[df[1] == 'val']], axis = 0)
test = df[df[1] == 'test']
train[[2,0]].to_csv(mallet_path + '/train.tsv', sep="\t", index=True, header=False)
train[[2,0]].to_csv(mallet_path + '/test.tsv', sep="\t", index=True, header=False)

# %%
mallet = pd.read_csv(mallet_path + '/corpus.tsv', sep="\t", header=None)
mallet
# Out:
#            0                       1  \
# 0          0            misc.forsale
# 1          1          comp.windows.x
# 2          2  soc.religion.christian
# 3          3      talk.religion.misc
# 4          4               rec.autos
# ...      ...                     ...
# 16304  16304            misc.forsale
# 16305  16305      talk.politics.guns
# 16306  16306   talk.politics.mideast
# 16307  16307               rec.autos
# 16308  16308                 sci.med
#
#                                                        2
# 0                               fax modem card sell mail
# 1                      run server server install run add
# 2      live part lead wait important remember judge j...
# 3                        doesn pain deserve die lie rape
# 4      sale mile good condition good condition player...
# ...                                                  ...
# 16304  summer great location university room large la...
# ...
